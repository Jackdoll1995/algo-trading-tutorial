# %% [markdown]
# # Binance Testnet

# %% [markdown]
# ## Prepare

# %%
from binance.client import Client
import pandas as pd

# %%
# %run "Projects/algo-trading-tutorial/api_keys_testnet.ipynb"
# Out:
# Stored 'api_key' (str)
# Stored 'secret_key' (str)

# %% [markdown]
# ## Testnet APIs

# %%
client = Client(api_key = api_key, api_secret = secret_key, testnet = True)

# %%
client

# %%
account = client.get_account()
account
# Out:
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00000000',
#   'taker': '0.00000000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1759567566123,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'ETH', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '4.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '1.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '10000.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '1478.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '170.00000000', 'locked': '0.00000000'},
# ...

# %%
df = pd.DataFrame(account['balances'])
df
# Out:
#     asset            free      locked
# 0     ETH      1.00000000  0.00000000
# 1     BTC      1.00000000  0.00000000
# 2     LTC      4.00000000  0.00000000
# 3     BNB      1.00000000  0.00000000
# 4    USDT  10000.00000000  0.00000000
# ..    ...             ...         ...
# 433   XPL    479.00000000  0.00000000
# 434  MIRA    815.00000000  0.00000000
# 435    FF   2549.00000000  0.00000000
# 436  EDEN   1196.00000000  0.00000000
# 437   NOM  11666.00000000  0.00000000
#
# [438 rows x 3 columns]

# %%
# Get JPY balance
# df[df['asset'] == 'JPY']
client.get_asset_balance(asset='JPY')
# Out:
# {'asset': 'JPY', 'free': '18466.00000000', 'locked': '0.00000000'}

# %%
client.get_symbol_ticker(symbol="BTCJPY")
# Out:
# {'symbol': 'BTCJPY', 'price': '18833900.00000000'}

# %% [markdown]
# ## Place a Market Buy Order

# %%
order = client.create_order(symbol='BTCJPY', side='BUY', type='MARKET', quantity=0.001)
